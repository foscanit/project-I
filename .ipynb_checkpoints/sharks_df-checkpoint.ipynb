# %%
# Import libraries

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import numpy as np
import os

# %%
# Import file and create dataframe

csv_file = 'attacks.csv'
sharks = pd.read_csv(csv_file, encoding='ISO-8859-1')
sharks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Check the number of rows and columns in the dataframe

sharks.shape
# Out:
# (25723, 24)

# %%
# Check the names of the columns

sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Rename the columns with a comprehension list

sharks.columns = [i.lower().replace(" ", "_") for i in sharks.columns]
sharks
# Out:
#       case_number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area                        location     activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Check the datatypes of the dataframe

sharks.dtypes
# Out:
# case_number                object
# date                       object
# year                      float64
# type                       object
# country                    object
# area                       object
# location                   object
# activity                   object
# name                       object
# sex_                       object
# age                        object
# injury                     object
# fatal_(y/n)                object
# time                       object
# species_                   object
# investigator_or_source     object
# pdf                        object
# href_formula               object
# href                       object
# case_number.1              object
# case_number.2              object
# original_order            float64
# unnamed:_22                object
# unnamed:_23                object
# dtype: object

# %%
sharks.value_counts('Sex ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sharks.value_counts('Sex ')
#
# File ~/miniconda3/envs/ironhack/lib/python3.11/site-packages/pandas/core/frame.py:7267, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7264     subset = self.columns.tolist()
#    7266 name = "proportion" if normalize else "count"
# -> 7267 counts = self.groupby(subset, dropna=dropna, observed=False).grouper.size()
#    7268 counts.name = name
#    7270 if sort:
#
# File ~/miniconda3/envs/ironhack/lib/python3.11/site-packages/pandas/core/frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
# ...

# %%
pd.DataFrame(sharks.value_counts('Sex ')).sample(2)

# %%
sharks.value_counts('Date')

# %%
pd.DataFrame(sharks.value_counts('Date')).sample(6)

# %%
sharks.value_counts('Year')

# %%
pd.DataFrame(sharks.value_counts('Year')).sample(6)

# %%
sharks.value_counts('Country')

# %%
pd.DataFrame(sharks.value_counts('Country')).sample(6)

# %%
sharks.value_counts('Type')

# %%
sharks.value_counts('Activity')

# %%
sharks.value_counts('Age')

# %%
sharks.value_counts('Injury')

# %%
sharks.value_counts('Fatal (Y/N)')

# %%
sharks.value_counts('Area')

# %%
sharks.value_counts('Location')

# %%
sharks.value_counts('Species ')

# %%
pd.DataFrame(sharks.value_counts('Species ')).sample(6)

# %%
sharks.value_counts('Time')

# %%
attacks.dropna(how='all')

# %%
# Queries with re (regular expressions): regex (regex101.com)

#\d (digits \d{6,8}) (six-eight digits)

# %% [markdown]
# Actions:
# 1) Drop all the empty values.
# 2) Drop unnamed columns.
# 3) Make values more standard --> clean with re?
#
# Questions: (I should choose between 3-5 questions).
# 1) The people who **provoked** the shark attacks, sex & age? Where were they from, to which culture belonged? Which activities were doing?
# 2) Meaning or things in common in the Invalid attacks.
# 3) Which kind of shark has provoked more attacks?
# 4) Which kind of shark has provoked more lethal attacks?
# 5) **In which regions have occurred more shark attacks? Relationship with the type of shark? Is it possible there is a relationship with the human culture or the climate change/ human activities affecting these regions, and these sharks are lacking food, thus they attack more?**
# 6) **Year by year, have the attacks increased generally, diminished or have aprox the same number? Sort by year, cronologically.**
# 7) what kind of people were more attacked by sharks? Age & gender.
# 8) In which moment of the day were there more attacks?
# 9) types of injury
# 10) Fatality
# 11) Is there a correlation between the number of the shark attacks and the seasons of the year?
# 12) How many unprovoked attacks are compared with the provoked ones?
#
# Types of plots I could use: matplotlib & seaborn
# - barcharts
# - lineplots
# - scatters
# - pie charts
